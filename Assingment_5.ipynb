# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
L=r'C:\\Users\\DELL\\Downloads\\Assingment_5\\Weater_Data.csv'
Data=pd.read_csv(L)
Data
# Out:
#     Janurary  Temperature_Max(°F)  Temperature_Avg  Temperature_Min  pm25  \
# 0          1                   54             50.5               47   152
# 1          2                   60             50.3               37   167
# 2          3                   37             30.4               24   376
# 3          4                   37             29.2               21   235
# 4          5                   41             33.2               25   344
# 5          6                   36             31.6               27   237
# 6          7                   28             26.7               23   165
# 7          8                   30             24.0               19   107
# 8          9                   36             30.9               22   159
# 9         10                   37             27.6               24   139
# 10        11                   24             20.8               18   153
# 11        12                   34             25.7               15   156
# ...

# %%
#check data type of All Columns
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Janurary             31 non-null     int64
#  1   Temperature_Max(°F)  31 non-null     int64
#  2   Temperature_Avg      31 non-null     float64
#  3   Temperature_Min      31 non-null     int64
#  4   pm25                 31 non-null     int64
#  5   pm10                 31 non-null     int64
#  6   o3                   31 non-null     int64
#  7   no2                  31 non-null     int64
#  8   so2                  31 non-null     int64
#  9    co                  31 non-null     int64
#  10  Humidity_Max(%)      31 non-null     int64
#  11  Humidity_AVg(%)      31 non-null     float64
#  12  Humidity_Min(%)      31 non-null     int64
#  13  Wind_Speed_Max(mph)  31 non-null     int64
#  14  Wind_Speed_Avgmph)   31 non-null     float64
# ...

# %%
#Descriptive statistics for all column 
Data.describe()
# Out:
#         Janurary  Temperature_Max(°F)  Temperature_Avg  Temperature_Min  \
# count  31.000000            31.000000        31.000000        31.000000
# mean   16.000000            35.161290        28.622581        21.354839
# std     9.092121             8.206082         7.976829         7.947949
# min     1.000000            20.000000        16.900000         9.000000
# 25%     8.500000            30.000000        21.850000        15.500000
# 50%    16.000000            36.000000        29.200000        22.000000
# 75%    23.500000            37.500000        32.650000        25.000000
# max    31.000000            60.000000        50.500000        47.000000
#
#              pm25        pm10         o3        no2        so2         co  \
# count   31.000000   31.000000  31.000000  31.000000  31.000000  31.000000
# mean   152.451613  107.129032  31.322581  10.451613  10.258065  10.225806
# std     68.190341   66.246379   8.665591   3.585514   3.651189   4.325966
# ...

# %%
#check null values in for data cleaning 
Data.isnull().sum()
# Out:
# Janurary               0
# Temperature_Max(°F)    0
# Temperature_Avg        0
# Temperature_Min        0
# pm25                   0
# pm10                   0
# o3                     0
# no2                    0
# so2                    0
#  co                    0
# Humidity_Max(%)        0
# Humidity_AVg(%)        0
# Humidity_Min(%)        0
# Wind_Speed_Max(mph)    0
# Wind_Speed_Avgmph)     0
# Wind_Speed_Min(mph)    0
# Precipitation (in)     0
# dtype: int64

# %%
# drop duplicate value from januray column(date cant be duplicate)
Data.drop_duplicates(subset='Janurary')
# Out:
#     Janurary  Temperature_Max(°F)  Temperature_Avg  Temperature_Min  pm25  \
# 0          1                   54             50.5               47   152
# 1          2                   60             50.3               37   167
# 2          3                   37             30.4               24   376
# 3          4                   37             29.2               21   235
# 4          5                   41             33.2               25   344
# 5          6                   36             31.6               27   237
# 6          7                   28             26.7               23   165
# 7          8                   30             24.0               19   107
# 8          9                   36             30.9               22   159
# 9         10                   37             27.6               24   139
# 10        11                   24             20.8               18   153
# 11        12                   34             25.7               15   156
# ...

# %%
# see the First 5 Rows 
Data.head(5)
# Out:
#    Janurary  Temperature_Max(°F)  Temperature_Avg  Temperature_Min  pm25  \
# 0         1                   54             50.5               47   152
# 1         2                   60             50.3               37   167
# 2         3                   37             30.4               24   376
# 3         4                   37             29.2               21   235
# 4         5                   41             33.2               25   344
#
#    pm10  o3  no2  so2   co  Humidity_Max(%)  Humidity_AVg(%)  Humidity_Min(%)  \
# 0   101  41   17   15   13               94             89.4               86
# 1   352  22   13   22   21               93             84.6               60
# 2   161  33    8   13   19               67             56.5               45
# 3   300  37   16    9   16               72             56.6               46
# 4   160  22   18    5   23               85             72.7               60
#
# ...

# %%
#Check the data type of Humidity_Max(%)
Data['Humidity_Max(%)'].dtype
# Out:
# dtype('int64')

# %%
# checking 0th row of Wind_Speed_Min(mph)
filtered_Data = Data[Data['Wind_Speed_Min(mph)'] == 0]
filtered_Data
# Out:
#     Janurary  Temperature_Max(°F)  Temperature_Avg  Temperature_Min  pm25  \
# 0          1                   54             50.5               47   152
# 1          2                   60             50.3               37   167
# 3          4                   37             29.2               21   235
# 4          5                   41             33.2               25   344
# 5          6                   36             31.6               27   237
# 6          7                   28             26.7               23   165
# 7          8                   30             24.0               19   107
# 8          9                   36             30.9               22   159
# 11        12                   34             25.7               15   156
# 12        13                   42             33.4               25   167
# 14        15                   20             16.9               13   155
# 15        16                   32             19.8                9   153
# ...

# %%
Data.groupby('Janurary')[['Humidity_AVg(%)']].sum().plot(kind='bar',stacked=True,color='red', edgecolor='black')
plt.ylabel('Humidity in %')
plt.title('Humidity variance(AVG) in JAN Month')
# Out:
# Text(0.5, 1.0, 'Humidity variance(AVG) in JAN Month')

# %%
Data.groupby('Janurary')[['Temperature_Max(°F)','Temperature_Min']].sum().plot(kind='line')
plt.ylabel('Tamprature in Fah')
plt.title('Temprature variance(MAX to MIN) in JAN Month')
# Out:
# Text(0.5, 1.0, 'Temprature variance(MAX to MIN) in JAN Month')

# %%
Data.groupby('Janurary')[['Wind_Speed_Avgmph)']].sum().plot(kind='area',stacked=True)
plt.ylabel('Wind_Speed in mph')
plt.title('Wind_Speed variance(MAX to MIN) in JAN Month')
# Out:
# Text(0.5, 1.0, 'Wind_Speed variance(MAX to MIN) in JAN Month')

# %%
#Regression Analysis for check important parameter who affecting the Precipitation(Rain)

# %%
#Define Independent Variables columns
IV=Data[['Temperature_Max(°F)', 'Temperature_Avg', 'Temperature_Min',
       'pm25', 'pm10', 'o3', 'no2', 'so2', ' co', 'Humidity_Max(%)',
       'Humidity_AVg(%)', 'Humidity_Min(%)', 'Wind_Speed_Max(mph)',
       'Wind_Speed_Avgmph)', 'Wind_Speed_Min(mph)']]

# %%
#define Dependent column for Pedictive analysis 

DV=Data['Precipitation (in)']

# %%
#checking data of dependent variable column
DV
# Out:
# 0     0.01
# 1     0.77
# 2     0.00
# 3     0.00
# 4     0.00
# 5     0.00
# 6     0.41
# 7     0.00
# 8     0.00
# 9     0.25
# 10    0.00
# 11    0.00
# 12    0.00
# 13    0.00
# 14    0.00
# 15    0.00
# 16    1.10
# 17    0.06
# 18    0.00
# 19    0.00
# 20    0.05
# 21    0.00
# 22    0.00
# 23    0.01
# 24    0.00
# 25    0.00
# 26    0.00
# 27    0.01
# 28    0.06
# 29    0.00
# 30    0.00
# Name: Precipitation (in), dtype: float64

# %%
#IMPORT library of sklearn and module feature_selection
from sklearn.feature_selection import mutual_info_regression

# %%
#Score Analysis on dependent variable due independent Columns
scores = mutual_info_regression(IV,DV)

# %%
# check column name inside the Independent variable 
IV.columns
# Out:
# Index(['Temperature_Max(°F)', 'Temperature_Avg', 'Temperature_Min', 'pm25',
#        'pm10', 'o3', 'no2', 'so2', ' co', 'Humidity_Max(%)', 'Humidity_AVg(%)',
#        'Humidity_Min(%)', 'Wind_Speed_Max(mph)', 'Wind_Speed_Avgmph)',
#        'Wind_Speed_Min(mph)'],
#       dtype='object')

# %%
#display scores of feature  information regretion
scores
# Out:
# array([0.        , 0.02182292, 0.00221698, 0.        , 0.        ,
#        0.01363031, 0.08064119, 0.03605051, 0.        , 0.        ,
#        0.04844675, 0.        , 0.11667557, 0.16180419, 0.06614688])

# %%
# change matrix to pandas series
scores_ser = pd.Series(scores)

# %%
scores_ser
# Out:
# 0     0.000000
# 1     0.021823
# 2     0.002217
# 3     0.000000
# 4     0.000000
# 5     0.013630
# 6     0.080641
# 7     0.036051
# 8     0.000000
# 9     0.000000
# 10    0.048447
# 11    0.000000
# 12    0.116676
# 13    0.161804
# 14    0.066147
# dtype: float64

# %%
scores_ser.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
scores_ser.index = IV.columns

# %%
scores_ser
# Out:
# Temperature_Max(°F)    0.000000
# Temperature_Avg        0.021823
# Temperature_Min        0.002217
# pm25                   0.000000
# pm10                   0.000000
# o3                     0.013630
# no2                    0.080641
# so2                    0.036051
#  co                    0.000000
# Humidity_Max(%)        0.000000
# Humidity_AVg(%)        0.048447
# Humidity_Min(%)        0.000000
# Wind_Speed_Max(mph)    0.116676
# Wind_Speed_Avgmph)     0.161804
# Wind_Speed_Min(mph)    0.066147
# dtype: float64

# %%
scores_ser.sort_values(ascending=False)
# Out:
# Wind_Speed_Avgmph)     0.161804
# Wind_Speed_Max(mph)    0.116676
# no2                    0.080641
# Wind_Speed_Min(mph)    0.066147
# Humidity_AVg(%)        0.048447
# so2                    0.036051
# Temperature_Avg        0.021823
# o3                     0.013630
# Temperature_Min        0.002217
# Temperature_Max(°F)    0.000000
# pm25                   0.000000
# pm10                   0.000000
#  co                    0.000000
# Humidity_Max(%)        0.000000
# Humidity_Min(%)        0.000000
# dtype: float64

# %%
scores_ser.sort_values(ascending=False).plot(kind = "bar")
plt.title(' Features Predicting Precipitation')
# Out:
# Text(0.5, 1.0, ' Features Predicting Precipitation')

# %%
# this shows thatTemperature_Min,PM25,PM10,CO. HUMIDITYMAX and Min low impacting the Precipitation

# %%
#Corealtion matrix for Wheater Data
Corrr_relation=Data.corr()

# %%
Corrr_relation
# Out:
#                      Janurary  Temperature_Max(°F)  Temperature_Avg  \
# Janurary             1.000000            -0.432914        -0.493108
# Temperature_Max(°F) -0.432914             1.000000         0.942626
# Temperature_Avg     -0.493108             0.942626         1.000000
# Temperature_Min     -0.524007             0.804042         0.932580
# pm25                -0.686189             0.216637         0.219765
# pm10                -0.494311             0.458427         0.411012
# o3                   0.268651            -0.035444        -0.063714
# no2                 -0.503069             0.275002         0.284120
# so2                 -0.314285             0.411310         0.338221
#  co                 -0.527981             0.490030         0.434149
# Humidity_Max(%)     -0.238203             0.652918         0.701185
# Humidity_AVg(%)     -0.368650             0.741112         0.799383
# Humidity_Min(%)     -0.543116             0.660519         0.749598
# ...

# %%
# Heat map for Correlation

plt.figure(figsize=(12, 10))
sns.heatmap(Corrr_relation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
